# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
crypto=pd.read_csv("D:\crypto_daily_prices (1).csv")

# %%
crypto
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]

# %%
crypto.isnull().sum()
# Out:
# Date               0
# BTC-USD Price      0
# ETH-USD Price    324
# LTC-USD Price      0
# dtype: int64

# %%
crypto.fillna(method='ffill',inplace=True)
crypto.plot(x='Date',y='BTC-USD Price')
# Out:
# C:\Users\aryas\AppData\Local\Temp\ipykernel_6060\1968867148.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   crypto.fillna(method='ffill',inplace=True)
# <Axes: xlabel='Date'>

# %%
crypto.plot(x='Date',y='BTC-USD Price',label='Bitcoin Price',linewidth=1.5,figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
crypto.plot(x='Date',y='BTC-USD Price',label='Bitcoin Price',linewidth=3,figsize=(14,6))
plt.ylabel('Price[$]')
plt.xlabel('Date')
plt.title('My First Data Visualization')
plt.legend(loc="upper left")
plt.grid()

# %%
crypto.plot(x='Date',y='BTC-USD Price',label='Bitcoin Price',linewidth=3,figsize=(14,6))
plt.ylabel('Price[$]')
plt.title('My First Data Visualization Exercise')
plt.legend(loc="upper left")
plt.grid()

# %%
crypto.plot(x='Date',y='ETH-USD Price',label='Bitcoin',linewidth=2.5,figsize=(10,5),color='b')
plt.ylabel('Price[$]',color='Black',fontsize=11,fontname="ALGERIAN")
plt.xlabel('Date',fontsize=17,fontname='ALGERIAN')
plt.title('My First Data Visualization Exercise',color='Black',fontsize=17,fontname='Snap ITC')
plt.legend(loc="upper left")
plt.grid(linewidth=2)

# %%
# !pip install yfinance
# Out:
# ...
#   Using cached yfinance-0.2.40-py2.py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached frozendict-2.4.4-py311-none-any.whl.metadata (23 kB)
# ...
#   Using cached peewee-3.17.5.tar.gz (3.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/73.5 kB ? eta -:--:--
#    -------------------------------------- - 71.7/73.5 kB 975.2 kB/s eta 0:00:01
#    ---------------------------------------- 73.5/73.5 kB 801.2 kB/s eta 0:00:00
# ...

# %%
import yfinance as yf

# %%
x=["ETH-USD"]
start=datetime.datetime(2010,1,1)
end=datetime.datetime(2022,5,16)

df=yf.download(x,start=start,end=end)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003   320.884003
# 2017-11-10   320.670990   324.717987   294.541992   299.252991   299.252991
# 2017-11-11   298.585999   319.453003   298.191986   314.681000   314.681000
# 2017-11-12   314.690002   319.153015   298.513000   307.907990   307.907990
# 2017-11-13   307.024994   328.415009   307.024994   316.716003   316.716003
# ...                 ...          ...          ...          ...          ...
# 2022-05-11  2342.754150  2441.079346  2018.855591  2072.108643  2072.108643
# 2022-05-12  2072.504639  2170.458008  1748.303101  1961.701538  1961.701538
# 2022-05-13  1960.122559  2139.713379  1941.975952  2014.418213  2014.418213
# 2022-05-14  2014.280640  2063.429932  1956.572998  2056.273926  2056.273926
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2017-11-09   308.644989   329.451996   307.056000   320.884003
# 1    2017-11-10   320.670990   324.717987   294.541992   299.252991
# 2    2017-11-11   298.585999   319.453003   298.191986   314.681000
# 3    2017-11-12   314.690002   319.153015   298.513000   307.907990
# 4    2017-11-13   307.024994   328.415009   307.024994   316.716003
# ...         ...          ...          ...          ...          ...
# 1644 2022-05-11  2342.754150  2441.079346  2018.855591  2072.108643
# 1645 2022-05-12  2072.504639  2170.458008  1748.303101  1961.701538
# 1646 2022-05-13  1960.122559  2139.713379  1941.975952  2014.418213
# 1647 2022-05-14  2014.280640  2063.429932  1956.572998  2056.273926
# 1648 2022-05-15  2056.183105  2147.194336  2008.162720  2145.706787
#
#         Adj Close       Volume
# 0      320.884003    893249984
# 1      299.252991    885985984
# 2      314.681000    842300992
# ...

# %%
r=['BTC-USD']
start=datetime.datetime(2010,1,1)
end=datetime.datetime(2022,5,16)

df=yf.download(r,start=start,end=end)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2022-05-11  31016.183594  32013.402344  28170.414062  28936.355469
# 2022-05-12  28936.734375  30032.439453  26350.490234  29047.751953
# 2022-05-13  29030.910156  30924.802734  28782.330078  29283.103516
# 2022-05-14  29285.642578  30192.802734  28702.910156  30101.265625
# 2022-05-15  30098.585938  31308.191406  29527.740234  31305.113281
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2793 2022-05-11  31016.183594  32013.402344  28170.414062  28936.355469
# 2794 2022-05-12  28936.734375  30032.439453  26350.490234  29047.751953
# 2795 2022-05-13  29030.910156  30924.802734  28782.330078  29283.103516
# 2796 2022-05-14  29285.642578  30192.802734  28702.910156  30101.265625
# 2797 2022-05-15  30098.585938  31308.191406  29527.740234  31305.113281
#
#          Adj Close       Volume
# 0       457.334015     21056800
# 1       424.440002     34483200
# ...

# %%
r=['ETH-USD']
start=datetime.datetime(2010,1,1)
end=datetime.datetime(2021,5,16)

df=yf.download(r,start=start,end=end)
df

df.reset_index(inplace=True)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#            Date         Open         High          Low        Close  \
# 0    2017-11-09   308.644989   329.451996   307.056000   320.884003
# 1    2017-11-10   320.670990   324.717987   294.541992   299.252991
# 2    2017-11-11   298.585999   319.453003   298.191986   314.681000
# 3    2017-11-12   314.690002   319.153015   298.513000   307.907990
# 4    2017-11-13   307.024994   328.415009   307.024994   316.716003
# ...         ...          ...          ...          ...          ...
# 1279 2021-05-11  3948.271973  4178.208984  3783.889404  4168.701172
# 1280 2021-05-12  4174.635742  4362.350586  3785.848633  3785.848633
# 1281 2021-05-13  3828.918457  4032.563477  3549.407227  3715.148438
# 1282 2021-05-14  3720.122314  4171.017090  3703.399902  4079.057373
# 1283 2021-05-15  4075.951660  4129.185547  3638.122070  3638.122070
#
#         Adj Close       Volume
# 0      320.884003    893249984
# ...

# %%
crypto.plot(x='Date',y=["BTC-USD Price","ETH-USD Price","LTC-USD Price"],linewidth=2,figsize=(15,5))
plt.ylabel("Price")
plt.xlabel('Date')
plt.title("Crypto Prices")
plt.grid()

# %%
crypto.plot(x='Date',title='rypto Prices',subplots=True,grid=True,figsize=(15,25))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %% [markdown]
# SCATTERPLOT

# %%
crypto.plot.scatter(x ="BTC-USD Price",y="ETH-USD Price", grid = True ,figsize = (10,7))
# Out:
# <Axes: xlabel='BTC-USD Price', ylabel='ETH-USD Price'>

# %% [markdown]
# piechart

# %%
my_dict={'ravi%':[20,35,15,17,13]}

# %%
a=pd.DataFrame(data=my_dict,index=['BTC','ETH','LTC',"XRP",'ADA'])
a
# Out:
#      ravi%
# BTC     20
# ETH     35
# LTC     15
# XRP     17
# ADA     13

# %%
a.plot.pie(y="ravi%", figsize=(5,5),autopct='% .2f %%',pctdistance=0.5)
plt.title('CRYPTO PORTFOLIO PIE CHART')
# Out:
# Text(0.5, 1.0, 'CRYPTO PORTFOLIO PIE CHART')

# %%
explode=(0.1,0,0.1,0.1,0.1)
a.plot.pie(y="ravi%", figsize=(5,5),autopct='%.2f %%',pctdistance=0.5,explode=explode)
plt.title('CRYPTO PORTFOLIO PIE CHART')
# Out:
# Text(0.5, 1.0, 'CRYPTO PORTFOLIO PIE CHART')

# %% [markdown]
# Histograms

# %%
r=pd.read_csv("D:\crypto_daily_prices.csv")

# %%
r
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]

# %%
x=r['BTC-USD Price'].mean()
a=r['BTC-USD Price'].sum()

#num_bins=40
#plt.figure(figsize=(20,15))

r['BTC-USD Price'].plot.hist(bins= 40,alpha= 1,figsize= (12,6))
plt.grid()
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
x=r['BTC-USD Price'].std()
a=r['BTC-USD Price'].sum()

#num_bins=40
#plt.figure(figsize=(20,15))

r['BTC-USD Price'].plot.hist(bins= 40,alpha= 1,figsize= (12,6),color='black')
#plt.grid()
plt.ylabel('Probability')
plt.title('Histogram: x= '+str(x)+ ',a= ' +str(a))
# Out:
# Text(0.5, 1.0, 'Histogram: x= 9289.02250524239,a= 15435379.738852698')

# %% [markdown]
# BAR chat

# %%
labels=['a','b','c']
values=[1,4,10]
bars=plt.bar(labels,values)

patterns=['/','O','*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))


#bars[0].set_hatch('/')
#bars[1].set_hatch('O')
#bars[2].set_hatch('*')
plt.figure(figsize=(5,2))
#plt.show()
