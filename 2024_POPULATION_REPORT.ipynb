# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv(r"D:\2024Populations.csv")

# %%
df
# Out:
#      rank           country TwoLetterID  unMember    pop1980     pop2000  \
# 0       1             India          IN      True  696828385  1059633675
# 1       2             China          CN      True  982372466  1264099069
# 2       3     United States          US      True  223140018   282398554
# 3       4         Indonesia          ID      True  148177096   214072421
# 4       5          Pakistan          PK      True   80624057   154369924
# ..    ...               ...         ...       ...        ...         ...
# 229   230        Montserrat          MS     False      11452        5138
# 230   231  Falkland Islands          FK     False       2240        3080
# 231   232              Niue          NU     False       3637        2074
# 232   233           Tokelau          TK     False       1647        1666
# 233   234      Vatican City          VA      True        733         651
#
#         pop2010     pop2023     pop2024     pop2030     pop2050  landAreaKm  \
# ...

# %%
df.head(10)
# Out:
#    rank        country TwoLetterID  unMember    pop1980     pop2000  \
# 0     1          India          IN      True  696828385  1059633675
# 1     2          China          CN      True  982372466  1264099069
# 2     3  United States          US      True  223140018   282398554
# 3     4      Indonesia          ID      True  148177096   214072421
# 4     5       Pakistan          PK      True   80624057   154369924
# 5     6        Nigeria          NG      True   72951439   122851984
# 6     7         Brazil          BR      True  122288383   175873720
# 7     8     Bangladesh          BD      True   83929765   129193327
# 8     9         Russia          RU      True  138257420   146844839
# 9    10       Ethiopia          ET      True   34945469    67031867
#
#       pop2010     pop2023     pop2024     pop2030     pop2050  landAreaKm  \
# 0  1240613620  1428627663  1441719852  1514994080  1670490596   2973190.0
# ...

# %%
df.tail(10)
# Out:
#      rank                    country TwoLetterID  unMember  pop1980  pop2000  \
# 224   225                      Nauru          NR      True     7635    10377
# 225   226                     Tuvalu          TV      True     7731     9638
# 226   227          Wallis and Futuna          WF     False    11315    14723
# 227   228           Saint Barthelemy          BL     False     2983     7082
# 228   229  Saint Pierre and Miquelon          PM     False     6106     6274
# 229   230                 Montserrat          MS     False    11452     5138
# 230   231           Falkland Islands          FK     False     2240     3080
# 231   232                       Niue          NU     False     3637     2074
# 232   233                    Tokelau          TK     False     1647     1666
# 233   234               Vatican City          VA      True      733      651
#
#      pop2010  pop2023  pop2024  pop2030  pop2050  landAreaKm  2024YoYChange  \
# ...

# %%
df.isnull().sum()
# Out:
# rank                   0
# country                0
# TwoLetterID            1
# unMember               0
# pop1980                0
# pop2000                0
# pop2010                0
# pop2023                0
# pop2024                0
# pop2030                0
# pop2050                0
# landAreaKm             0
# 2024YoYChange          0
# 2024YoYGrowthRate      0
# 2024WorldPercentage    0
# Density_2024           0
# dtype: int64

# %%
df.dtypes
# Out:
# rank                     int64
# country                 object
# TwoLetterID             object
# unMember                  bool
# pop1980                  int64
# pop2000                  int64
# pop2010                  int64
# pop2023                  int64
# pop2024                  int64
# pop2030                  int64
# pop2050                  int64
# landAreaKm             float64
# 2024YoYChange            int64
# 2024YoYGrowthRate      float64
# 2024WorldPercentage    float64
# Density_2024           float64
# dtype: object

# %%
# Unique countries
print(f"Unique countries: {df['country'].nunique()}")
# Out:
# Unique countries: 234

# %%
df.shape
# Out:
# (234, 16)

# %% [markdown]
# # Visualization the distribution of the population in 2024.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))
sns.histplot(df['pop2024'], bins=30, kde=True)
plt.title('Distribution of 2024 Population')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Visualization the year-on-year population growth rate for 2024.

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df['2024YoYGrowthRate'], bins=30, kde=True)
plt.title('Distribution of 2024 Year-on-Year Population Growth Rate')
plt.xlabel('Growth Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#  # TOP 10 COUNTRIES BY POPULATION 2024

# %%
top_10_pop_2024 = df.sort_values(by='pop2024', ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x='pop2024', y='country', data=top_10_pop_2024)
plt.title('Top 10 Countries by Population in 2024')
plt.xlabel('Population')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# # TOP 10  LEAST POPULATED  COUNTRIES 2024

# %%
top_10_LEAST_pop_2024 = df.sort_values(by='pop2024', ascending=False).tail(10)
plt.figure(figsize=(12, 6))
sns.barplot(x='pop2024', y='country', data=top_10_LEAST_pop_2024)
plt.title('Top 10 Countries by Population in 2024')
plt.xlabel('Population')
plt.ylabel('Country')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Density_2024', y='landAreaKm', data=df)
plt.title('Population Density vs. Land Area in 2024')
plt.xlabel('Population Density (people per square km)')
plt.ylabel('Land Area (square km)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='pop2024', data=df)
plt.title('Distribution of Population in 2024')
plt.xlabel('Population')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['2024YoYChange'], bins=20, kde=True)
plt.title('Distribution of Population Change from 2023 to 2024')
plt.xlabel('Population Change')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # TOP 10 COUNTRIES POPULATION CHANGES FROM 2023 TO 2024

# %%
top_10_pop_change = df.sort_values(by='2024YoYChange', ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x='2024YoYChange', y='country', data=top_10_pop_change)
plt.title('Population Change from 2023 to 2024 (Top 10 Countries)')
plt.xlabel('Population Change')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# # 10 LEAST POPULATED COUNTRIES POPULATION CHANGES FROM 2023 TO 2024

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='2024YoYChange', y='country', data=top_10_LEAST_pop_2024)
plt.title('Top 10 Countries by Population Change from 2023 to 2024')
plt.xlabel('Population Change')
plt.ylabel('Country')
plt.show()

# %%
india_data = df[df['country'] == 'India']
plt.figure(figsize=(12, 6))
plt.plot(india_data.columns[4:11], india_data.iloc[0, 4:11], marker='o')
plt.title('Population Change in India (1980-2050)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.xticks(rotation=15)
plt.grid(True)
plt.show()

# %%
india_data = df[df['country'] == 'India']
years = ['1980', '2000', '2010', '2023', '2024', '2030', '2050']
populations = india_data.iloc[:, 4:11].values.flatten()
plt.figure(figsize=(10, 6))
plt.bar(years, populations, color=['blue', 'green', 'red', 'orange', 'purple', 'brown', 'pink'])
plt.title('Historical Populations in India')
plt.xlabel('Year')
plt.ylabel('Population')
plt.xticks(rotation=45)
plt.show()

# %%
Montserrat_data = df[df['country'] == 'Montserrat']
plt.figure(figsize=(12, 6))
plt.plot(Montserrat_data.columns[4:11], Montserrat_data.iloc[0, 4:11], marker='o')
plt.title('Population Change in Montserrat (1980-2050)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.xticks(rotation=15)
plt.grid(True)
plt.show()

# %%
sns.pairplot(df[['pop2024', 'pop2030', 'pop2050', 'landAreaKm', 'Density_2024']])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Density_2024', data=df)
plt.title('Population Density Distribution in 2024')
plt.xlabel('Population Density (people per square km)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(x='Density_2024', data=df)
plt.title('Population Density Distribution in 2024')
plt.xlabel('Population Density (people per square km)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df['Density_2024'], shade=True)
plt.title('Population Density Distribution in 2024')
plt.xlabel('Population Density (people per square km)')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='unMember', y='pop2024', data=df, estimator=sum)
plt.title('Total Population in 2024: UN Member vs. Non-Member Countries')
plt.xlabel('UN Membership')
plt.ylabel('Total Population')
plt.xticks([0, 1], ['Non-Member', 'Member'])
plt.show()

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
plt.figure(figsize=(10, 8))
sns.heatmap(df[numerical_columns].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Select features for clustering
features = df[['2024YoYGrowthRate', 'Density_2024']]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
import warnings
warnings.filterwarnings("ignore")

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(scaled_features)

# %% [markdown]
# # Visualize clusters

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='2024YoYGrowthRate', y='Density_2024', hue='Cluster', data=df, palette='viridis')
plt.title('Clusters of Countries by Growth Rate and Population Density')
plt.xlabel('2024 YoY Growth Rate')
plt.ylabel('2024 Population Density')
plt.legend(title='Cluster')
plt.show()

# %% [raw]
# Most countries fall into Cluster 0 (purple), indicating a wide range of growth rates but generally lower population densities.
#
# Cluster 1 (teal) contains countries with very high population density, significantly higher than the other clusters, and these countries do not show extreme growth rates.
#
# Cluster 2 (yellow) includes countries with moderate growth rates and varying densities, but generally higher than those in Cluster 0.
#
# A few outliers in Cluster 1 (teal) exhibit extraordinarily high population densities, suggesting these might be small but highly populated region

# %% [markdown]
# # Visualize Population Distribution by UN Membership

# %%
plt.figure(figsize=(14, 6))

# UN Members
plt.subplot(1, 2, 1)
sns.histplot(df[df['unMember'] == True]['pop2024'], bins=10, kde=True)
plt.title('2024 Population Distribution for UN Members')
plt.xlabel('Population')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # 2024 POPULATION DISTRIBUTION FOR NON-UN MENBERS

# %%
plt.figure(figsize=(14, 6))
# Non-UN Members
plt.subplot(1, 2, 2)
sns.histplot(df[df['unMember'] == False]['pop2024'], bins=30, kde=True)
plt.title('2024 Population Distribution for Non-UN Members')
plt.xlabel('Population')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # GROWTH RATE DISTRIBUTION FOR UN AND NON-UN MEMBERS

# %%
plt.figure(figsize=(14, 6))

# UN Members
plt.subplot(1, 2, 1)
sns.histplot(df[df['unMember'] == True]['2024YoYGrowthRate'], bins=30, kde=True)
plt.title('2024 YoY Growth Rate Distribution for UN Members')
plt.xlabel('Growth Rate (%)')
plt.ylabel('Frequency')

# Non-UN Members
plt.subplot(1, 2, 2)
sns.histplot(df[df['unMember'] == False]['2024YoYGrowthRate'], bins=30, kde=True)
plt.title('2024 YoY Growth Rate Distribution for Non-UN Members')
plt.xlabel('Growth Rate (%)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [raw]
# For UN member countries, there are a few countries with a negative growth rate, and a few countries with a growth rate above 4%.
#
# The distribution for non-UN member countries is more spread out than the distribution for UN member countries. There are non-UN member countries with a YoY growth rate below -5%

# %% [markdown]
# # Top 10 Most Populous Countries by UN Membership

# %%
# Top 10 UN Members
top_10_un_members = df[df['unMember'] == True].nlargest(10, 'pop2024')

plt.figure(figsize=(14, 6))

# UN Members
plt.subplot(1, 2, 1)
sns.barplot(x='pop2024', y='country', data=top_10_un_members)
plt.title('Top 10 Most Populous UN Member Countries in 2024')
plt.xlabel('Population')
plt.ylabel('Country')

# Top 10 Non-UN Members
top_10_non_un_members = df[df['unMember'] == False].nlargest(10, 'pop2024')

# Non-UN Members
plt.subplot(1, 2, 2)
sns.barplot(x='pop2024', y='country', data=top_10_non_un_members)
plt.title('Top 10 Most Populous Non-UN Member Countries in 2024')
plt.xlabel('Population')
plt.ylabel('Country')

plt.tight_layout()
plt.show()

# %%
express.scatter(data_frame=df, x='pop1980', y='pop2050', log_x=True, log_y=True, hover_name='country', color='2024YoYGrowthRate')
# Out:
# <div>                            <div id="851de4a3-32c3-4687-bc58-5737fafc828c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("851de4a3-32c3-4687-bc58-5737fafc828c")) {                    Plotly.newPlot(                        "851de4a3-32c3-4687-bc58-5737fafc828c",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>pop1980=%{x}<br>pop2050=%{y}<br>2024YoYGrowthRate=%{marker.color}<extra></extra>","hovertext":["India","China","United States","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh","Russia","Ethiopia","Mexico","Japan","Philippines","Egypt","DR Congo","Vietnam","Iran","Turkey","Germany","Thailand","Tanzania","United Kingdom","France","South Africa","Italy","Kenya","Myanmar","Colombia","South Korea","Uganda","Sudan","Sp
# ...
